# %% [markdown]
# # Activity 1.2 : Training Neural Networks

# %% [markdown]
# #### Objective(s):
#
# This activity aims to demonstrate how to train neural networks using keras

# %% [markdown]
# #### Intended Learning Outcomes (ILOs):
# * Demonstrate how to build and train neural networks
# * Demonstrate how to evaluate and plot the model using training and validation loss

# %% [markdown]
# #### Resources:
# * Jupyter Notebook
#
# CI Pima Diabetes Dataset
#
# * pima-indians-diabetes.csv

# %% [markdown]
# #### Procedures

# %% [markdown]
# Load the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_auc_score, roc_curve, accuracy_score
from sklearn.ensemble import RandomForestClassifier

import seaborn as sns

# %matplotlib inline

# %%
## Import Keras objects for Deep Learning

from keras.models  import Sequential
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.optimizers import Adam, SGD, RMSprop

# %% [markdown]
# Load the dataset

# %%
filepath = "pima-indians-diabetes.csv"
names = ["times_pregnant", "glucose_tolerance_test", "blood_pressure", "skin_thickness", "insulin", 
         "bmi", "pedigree_function", "age", "has_diabetes"]
diabetes_df = pd.read_csv(filepath, names=names)

# %% [markdown]
# Check the top 5 samples of the data

# %%
print(diabetes_df.shape)
diabetes_df.sample(5)
# Out:
# (768, 9)
#      times_pregnant  glucose_tolerance_test  blood_pressure  skin_thickness  \
# 507               1                     130              60              23
# 50                1                     103              80              11
# 301               2                     144              58              33
# 503               7                      94              64              25
# 348               3                      99              62              19
#
#      insulin   bmi  pedigree_function  age  has_diabetes
# 507      170  28.6              0.692   21             0
# 50        82  19.4              0.491   22             0
# 301      135  31.6              0.422   25             1
# 503       79  33.3              0.738   41             0
# 348       74  21.8              0.279   26             0

# %%
diabetes_df.dtypes
# Out:
# times_pregnant              int64
# glucose_tolerance_test      int64
# blood_pressure              int64
# skin_thickness              int64
# insulin                     int64
# bmi                       float64
# pedigree_function         float64
# age                         int64
# has_diabetes                int64
# dtype: object

# %%
X = diabetes_df.iloc[:, :-1].values
y = diabetes_df["has_diabetes"].values

# %% [markdown]
# Split the data to Train, and Test (75%, 25%)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=11111)

# %%
np.mean(y), np.mean(1-y)
# Out:
# (0.3489583333333333, 0.6510416666666666)

# %% [markdown]
# Build a single hidden layer neural network using 12 nodes.
# Use the sequential model with single layer network and input shape to 8.

# %% [markdown]
# Normalize the data

# %%
normalizer = StandardScaler()
X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.transform(X_test)

# %% [markdown]
# Define the model:
# * Input size is 8-dimensional
# * 1 hidden layer, 12 hidden nodes, sigmoid activation
# * Final layer with one node and sigmoid activation (standard for binary classification)

# %%
model = Sequential([
    Dense(12, input_shape=(8,), activation="relu"),
    Dense(1, activation="sigmoid")
])

# %% [markdown]
# View the model summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                108
#
#  dense_1 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model
# * Compile the model with optimizer, loss function and metrics
# * Use the fit function to return the run history.

# %%
model.compile(SGD(lr = .003), "binary_crossentropy", metrics=["accuracy"])
run_hist_1 = model.fit(X_train_norm, y_train, validation_data=(X_test_norm, y_test), epochs=200)
# Out:
# Epoch 1/200
# c:\Users\User\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 18/18 [==============================] - 2s 7ms/step - loss: 0.7835 - accuracy: 0.4462 - val_loss: 0.8099 - val_accuracy: 0.4062
# Epoch 2/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7699 - accuracy: 0.4549 - val_loss: 0.7961 - val_accuracy: 0.4167
# Epoch 3/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7573 - accuracy: 0.4653 - val_loss: 0.7834 - val_accuracy: 0.4323
# Epoch 4/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7455 - accuracy: 0.4774 - val_loss: 0.7714 - val_accuracy: 0.4479
# Epoch 5/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7345 - accuracy: 0.4844 - val_loss: 0.7602 - val_accuracy: 0.4531
# Epoch 6/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7241 - accuracy: 0.4948 - val_loss: 0.7496 - val_accuracy: 0.4583
# Epoch 7/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7143 - accuracy: 0.5052 - val_loss: 0.7397 - val_accuracy: 0.4844
# Epoch 8/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.7052 - accuracy: 0.5295 - val_loss: 0.7303 - val_accuracy: 0.5000
# Epoch 9/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6966 - accuracy: 0.5399 - val_loss: 0.7215 - val_accuracy: 0.5104
# Epoch 10/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6884 - accuracy: 0.5642 - val_loss: 0.7132 - val_accuracy: 0.5208
# Epoch 11/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6806 - accuracy: 0.5747 - val_loss: 0.7054 - val_accuracy: 0.5417
# Epoch 12/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6734 - accuracy: 0.5885 - val_loss: 0.6980 - val_accuracy: 0.5469
# Epoch 13/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6665 - accuracy: 0.5955 - val_loss: 0.6910 - val_accuracy: 0.5573
# Epoch 14/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6600 - accuracy: 0.5990 - val_loss: 0.6843 - val_accuracy: 0.5781
# Epoch 15/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6538 - accuracy: 0.6076 - val_loss: 0.6779 - val_accuracy: 0.5885
# Epoch 16/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6480 - accuracy: 0.6198 - val_loss: 0.6719 - val_accuracy: 0.5990
# Epoch 17/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6424 - accuracy: 0.6337 - val_loss: 0.6661 - val_accuracy: 0.6198
# Epoch 18/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6371 - accuracy: 0.6337 - val_loss: 0.6606 - val_accuracy: 0.6302
# Epoch 19/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6424 - val_loss: 0.6554 - val_accuracy: 0.6250
# Epoch 20/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6273 - accuracy: 0.6441 - val_loss: 0.6504 - val_accuracy: 0.6406
# Epoch 21/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6227 - accuracy: 0.6528 - val_loss: 0.6456 - val_accuracy: 0.6510
# Epoch 22/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6183 - accuracy: 0.6562 - val_loss: 0.6410 - val_accuracy: 0.6562
# Epoch 23/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6141 - accuracy: 0.6615 - val_loss: 0.6366 - val_accuracy: 0.6615
# Epoch 24/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6102 - accuracy: 0.6684 - val_loss: 0.6324 - val_accuracy: 0.6562
# Epoch 25/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6063 - accuracy: 0.6719 - val_loss: 0.6284 - val_accuracy: 0.6562
# Epoch 26/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6027 - accuracy: 0.6806 - val_loss: 0.6246 - val_accuracy: 0.6562
# Epoch 27/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5992 - accuracy: 0.6875 - val_loss: 0.6209 - val_accuracy: 0.6562
# Epoch 28/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5958 - accuracy: 0.6927 - val_loss: 0.6173 - val_accuracy: 0.6667
# Epoch 29/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5925 - accuracy: 0.6892 - val_loss: 0.6138 - val_accuracy: 0.6667
# Epoch 30/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5894 - accuracy: 0.6910 - val_loss: 0.6105 - val_accuracy: 0.6667
# Epoch 31/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5863 - accuracy: 0.6910 - val_loss: 0.6073 - val_accuracy: 0.6719
# Epoch 32/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5834 - accuracy: 0.6927 - val_loss: 0.6041 - val_accuracy: 0.6719
# Epoch 33/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5805 - accuracy: 0.6944 - val_loss: 0.6011 - val_accuracy: 0.6667
# Epoch 34/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5778 - accuracy: 0.6997 - val_loss: 0.5983 - val_accuracy: 0.6667
# Epoch 35/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5752 - accuracy: 0.7066 - val_loss: 0.5955 - val_accuracy: 0.6719
# Epoch 36/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5726 - accuracy: 0.7101 - val_loss: 0.5928 - val_accuracy: 0.6771
# Epoch 37/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5701 - accuracy: 0.7083 - val_loss: 0.5901 - val_accuracy: 0.6719
# Epoch 38/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5677 - accuracy: 0.7188 - val_loss: 0.5876 - val_accuracy: 0.6719
# Epoch 39/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5653 - accuracy: 0.7205 - val_loss: 0.5851 - val_accuracy: 0.6667
# Epoch 40/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5631 - accuracy: 0.7222 - val_loss: 0.5827 - val_accuracy: 0.6719
# Epoch 41/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5609 - accuracy: 0.7240 - val_loss: 0.5804 - val_accuracy: 0.6719
# Epoch 42/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5588 - accuracy: 0.7257 - val_loss: 0.5782 - val_accuracy: 0.6823
# Epoch 43/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5567 - accuracy: 0.7292 - val_loss: 0.5760 - val_accuracy: 0.6979
# Epoch 44/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5547 - accuracy: 0.7326 - val_loss: 0.5739 - val_accuracy: 0.6979
# Epoch 45/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5528 - accuracy: 0.7326 - val_loss: 0.5719 - val_accuracy: 0.6979
# Epoch 46/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5508 - accuracy: 0.7378 - val_loss: 0.5699 - val_accuracy: 0.7031
# Epoch 47/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5490 - accuracy: 0.7378 - val_loss: 0.5679 - val_accuracy: 0.7083
# Epoch 48/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5472 - accuracy: 0.7431 - val_loss: 0.5661 - val_accuracy: 0.7083
# Epoch 49/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.7431 - val_loss: 0.5642 - val_accuracy: 0.7083
# Epoch 50/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5437 - accuracy: 0.7413 - val_loss: 0.5624 - val_accuracy: 0.7083
# Epoch 51/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5420 - accuracy: 0.7431 - val_loss: 0.5607 - val_accuracy: 0.7135
# Epoch 52/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5404 - accuracy: 0.7465 - val_loss: 0.5590 - val_accuracy: 0.7188
# Epoch 53/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5388 - accuracy: 0.7431 - val_loss: 0.5574 - val_accuracy: 0.7188
# Epoch 54/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5372 - accuracy: 0.7431 - val_loss: 0.5558 - val_accuracy: 0.7240
# Epoch 55/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5357 - accuracy: 0.7413 - val_loss: 0.5542 - val_accuracy: 0.7240
# Epoch 56/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5341 - accuracy: 0.7396 - val_loss: 0.5527 - val_accuracy: 0.7188
# Epoch 57/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5327 - accuracy: 0.7413 - val_loss: 0.5512 - val_accuracy: 0.7240
# Epoch 58/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5312 - accuracy: 0.7431 - val_loss: 0.5497 - val_accuracy: 0.7188
# Epoch 59/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5298 - accuracy: 0.7431 - val_loss: 0.5483 - val_accuracy: 0.7135
# Epoch 60/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5285 - accuracy: 0.7465 - val_loss: 0.5469 - val_accuracy: 0.7188
# Epoch 61/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5271 - accuracy: 0.7465 - val_loss: 0.5455 - val_accuracy: 0.7188
# Epoch 62/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5258 - accuracy: 0.7465 - val_loss: 0.5441 - val_accuracy: 0.7240
# Epoch 63/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5245 - accuracy: 0.7465 - val_loss: 0.5428 - val_accuracy: 0.7292
# Epoch 64/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5232 - accuracy: 0.7448 - val_loss: 0.5416 - val_accuracy: 0.7292
# Epoch 65/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5220 - accuracy: 0.7448 - val_loss: 0.5403 - val_accuracy: 0.7344
# Epoch 66/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5207 - accuracy: 0.7448 - val_loss: 0.5391 - val_accuracy: 0.7344
# Epoch 67/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5195 - accuracy: 0.7431 - val_loss: 0.5379 - val_accuracy: 0.7344
# Epoch 68/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5184 - accuracy: 0.7431 - val_loss: 0.5367 - val_accuracy: 0.7344
# Epoch 69/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5172 - accuracy: 0.7465 - val_loss: 0.5355 - val_accuracy: 0.7344
# Epoch 70/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5161 - accuracy: 0.7448 - val_loss: 0.5344 - val_accuracy: 0.7344
# Epoch 71/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5149 - accuracy: 0.7448 - val_loss: 0.5333 - val_accuracy: 0.7344
# Epoch 72/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5138 - accuracy: 0.7483 - val_loss: 0.5322 - val_accuracy: 0.7344
# Epoch 73/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5128 - accuracy: 0.7483 - val_loss: 0.5311 - val_accuracy: 0.7344
# Epoch 74/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5117 - accuracy: 0.7465 - val_loss: 0.5301 - val_accuracy: 0.7396
# Epoch 75/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5107 - accuracy: 0.7500 - val_loss: 0.5291 - val_accuracy: 0.7396
# Epoch 76/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5096 - accuracy: 0.7465 - val_loss: 0.5281 - val_accuracy: 0.7396
# Epoch 77/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5086 - accuracy: 0.7465 - val_loss: 0.5271 - val_accuracy: 0.7396
# Epoch 78/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5077 - accuracy: 0.7483 - val_loss: 0.5262 - val_accuracy: 0.7448
# Epoch 79/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5067 - accuracy: 0.7517 - val_loss: 0.5253 - val_accuracy: 0.7500
# Epoch 80/200
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5057 - accuracy: 0.7535 - val_loss: 0.5244 - val_accuracy: 0.7500
# Epoch 81/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5048 - accuracy: 0.7517 - val_loss: 0.5235 - val_accuracy: 0.7604
# Epoch 82/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5039 - accuracy: 0.7517 - val_loss: 0.5226 - val_accuracy: 0.7604
# Epoch 83/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5030 - accuracy: 0.7517 - val_loss: 0.5218 - val_accuracy: 0.7552
# Epoch 84/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5022 - accuracy: 0.7517 - val_loss: 0.5210 - val_accuracy: 0.7448
# Epoch 85/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5013 - accuracy: 0.7517 - val_loss: 0.5202 - val_accuracy: 0.7448
# Epoch 86/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5005 - accuracy: 0.7535 - val_loss: 0.5195 - val_accuracy: 0.7500
# Epoch 87/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4997 - accuracy: 0.7552 - val_loss: 0.5187 - val_accuracy: 0.7500
# Epoch 88/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4989 - accuracy: 0.7552 - val_loss: 0.5180 - val_accuracy: 0.7448
# Epoch 89/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4981 - accuracy: 0.7587 - val_loss: 0.5173 - val_accuracy: 0.7396
# Epoch 90/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.7604 - val_loss: 0.5166 - val_accuracy: 0.7396
# Epoch 91/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4965 - accuracy: 0.7587 - val_loss: 0.5159 - val_accuracy: 0.7396
# Epoch 92/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4958 - accuracy: 0.7587 - val_loss: 0.5153 - val_accuracy: 0.7396
# Epoch 93/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4951 - accuracy: 0.7587 - val_loss: 0.5146 - val_accuracy: 0.7396
# Epoch 94/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4944 - accuracy: 0.7587 - val_loss: 0.5140 - val_accuracy: 0.7396
# Epoch 95/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4936 - accuracy: 0.7569 - val_loss: 0.5134 - val_accuracy: 0.7396
# Epoch 96/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4930 - accuracy: 0.7587 - val_loss: 0.5127 - val_accuracy: 0.7396
# Epoch 97/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4922 - accuracy: 0.7604 - val_loss: 0.5122 - val_accuracy: 0.7396
# Epoch 98/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4916 - accuracy: 0.7622 - val_loss: 0.5116 - val_accuracy: 0.7396
# Epoch 99/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4909 - accuracy: 0.7639 - val_loss: 0.5110 - val_accuracy: 0.7396
# Epoch 100/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4903 - accuracy: 0.7656 - val_loss: 0.5104 - val_accuracy: 0.7396
# Epoch 101/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4896 - accuracy: 0.7656 - val_loss: 0.5099 - val_accuracy: 0.7448
# Epoch 102/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4890 - accuracy: 0.7656 - val_loss: 0.5093 - val_accuracy: 0.7396
# Epoch 103/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4883 - accuracy: 0.7656 - val_loss: 0.5088 - val_accuracy: 0.7396
# Epoch 104/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4877 - accuracy: 0.7674 - val_loss: 0.5083 - val_accuracy: 0.7396
# Epoch 105/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4871 - accuracy: 0.7674 - val_loss: 0.5077 - val_accuracy: 0.7396
# Epoch 106/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4865 - accuracy: 0.7674 - val_loss: 0.5072 - val_accuracy: 0.7396
# Epoch 107/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4859 - accuracy: 0.7691 - val_loss: 0.5068 - val_accuracy: 0.7396
# Epoch 108/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4854 - accuracy: 0.7691 - val_loss: 0.5063 - val_accuracy: 0.7396
# Epoch 109/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4848 - accuracy: 0.7691 - val_loss: 0.5058 - val_accuracy: 0.7396
# Epoch 110/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4842 - accuracy: 0.7691 - val_loss: 0.5054 - val_accuracy: 0.7396
# Epoch 111/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4837 - accuracy: 0.7674 - val_loss: 0.5049 - val_accuracy: 0.7396
# Epoch 112/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4832 - accuracy: 0.7691 - val_loss: 0.5045 - val_accuracy: 0.7396
# Epoch 113/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4826 - accuracy: 0.7674 - val_loss: 0.5041 - val_accuracy: 0.7448
# Epoch 114/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4821 - accuracy: 0.7674 - val_loss: 0.5037 - val_accuracy: 0.7448
# Epoch 115/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4816 - accuracy: 0.7656 - val_loss: 0.5033 - val_accuracy: 0.7448
# Epoch 116/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4811 - accuracy: 0.7691 - val_loss: 0.5029 - val_accuracy: 0.7448
# Epoch 117/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4806 - accuracy: 0.7691 - val_loss: 0.5025 - val_accuracy: 0.7448
# Epoch 118/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4801 - accuracy: 0.7708 - val_loss: 0.5021 - val_accuracy: 0.7448
# Epoch 119/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4796 - accuracy: 0.7708 - val_loss: 0.5017 - val_accuracy: 0.7448
# Epoch 120/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4791 - accuracy: 0.7708 - val_loss: 0.5014 - val_accuracy: 0.7448
# Epoch 121/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4786 - accuracy: 0.7708 - val_loss: 0.5010 - val_accuracy: 0.7448
# Epoch 122/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4782 - accuracy: 0.7726 - val_loss: 0.5006 - val_accuracy: 0.7448
# Epoch 123/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4777 - accuracy: 0.7708 - val_loss: 0.5003 - val_accuracy: 0.7448
# Epoch 124/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4772 - accuracy: 0.7708 - val_loss: 0.5000 - val_accuracy: 0.7448
# Epoch 125/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4768 - accuracy: 0.7726 - val_loss: 0.4996 - val_accuracy: 0.7500
# Epoch 126/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4763 - accuracy: 0.7726 - val_loss: 0.4993 - val_accuracy: 0.7500
# Epoch 127/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4759 - accuracy: 0.7708 - val_loss: 0.4990 - val_accuracy: 0.7500
# Epoch 128/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4755 - accuracy: 0.7726 - val_loss: 0.4987 - val_accuracy: 0.7500
# Epoch 129/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4750 - accuracy: 0.7726 - val_loss: 0.4984 - val_accuracy: 0.7500
# Epoch 130/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4747 - accuracy: 0.7708 - val_loss: 0.4981 - val_accuracy: 0.7500
# Epoch 131/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4742 - accuracy: 0.7743 - val_loss: 0.4978 - val_accuracy: 0.7500
# Epoch 132/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4738 - accuracy: 0.7760 - val_loss: 0.4975 - val_accuracy: 0.7500
# Epoch 133/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4734 - accuracy: 0.7760 - val_loss: 0.4972 - val_accuracy: 0.7500
# Epoch 134/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4730 - accuracy: 0.7726 - val_loss: 0.4970 - val_accuracy: 0.7552
# Epoch 135/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4726 - accuracy: 0.7760 - val_loss: 0.4967 - val_accuracy: 0.7552
# Epoch 136/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.7760 - val_loss: 0.4964 - val_accuracy: 0.7552
# Epoch 137/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4719 - accuracy: 0.7760 - val_loss: 0.4962 - val_accuracy: 0.7552
# Epoch 138/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4715 - accuracy: 0.7760 - val_loss: 0.4960 - val_accuracy: 0.7552
# Epoch 139/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4711 - accuracy: 0.7778 - val_loss: 0.4957 - val_accuracy: 0.7552
# Epoch 140/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4708 - accuracy: 0.7778 - val_loss: 0.4955 - val_accuracy: 0.7552
# Epoch 141/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4704 - accuracy: 0.7778 - val_loss: 0.4953 - val_accuracy: 0.7552
# Epoch 142/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4700 - accuracy: 0.7778 - val_loss: 0.4951 - val_accuracy: 0.7552
# Epoch 143/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4697 - accuracy: 0.7778 - val_loss: 0.4948 - val_accuracy: 0.7552
# Epoch 144/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4693 - accuracy: 0.7778 - val_loss: 0.4946 - val_accuracy: 0.7552
# Epoch 145/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4690 - accuracy: 0.7760 - val_loss: 0.4944 - val_accuracy: 0.7552
# Epoch 146/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4686 - accuracy: 0.7778 - val_loss: 0.4942 - val_accuracy: 0.7552
# Epoch 147/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4683 - accuracy: 0.7778 - val_loss: 0.4940 - val_accuracy: 0.7552
# Epoch 148/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4680 - accuracy: 0.7760 - val_loss: 0.4939 - val_accuracy: 0.7500
# Epoch 149/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4677 - accuracy: 0.7778 - val_loss: 0.4937 - val_accuracy: 0.7552
# Epoch 150/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4674 - accuracy: 0.7760 - val_loss: 0.4935 - val_accuracy: 0.7552
# Epoch 151/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4670 - accuracy: 0.7760 - val_loss: 0.4933 - val_accuracy: 0.7552
# Epoch 152/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4667 - accuracy: 0.7760 - val_loss: 0.4932 - val_accuracy: 0.7552
# Epoch 153/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4664 - accuracy: 0.7778 - val_loss: 0.4930 - val_accuracy: 0.7552
# Epoch 154/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4661 - accuracy: 0.7778 - val_loss: 0.4928 - val_accuracy: 0.7552
# Epoch 155/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4658 - accuracy: 0.7795 - val_loss: 0.4927 - val_accuracy: 0.7552
# Epoch 156/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4655 - accuracy: 0.7760 - val_loss: 0.4925 - val_accuracy: 0.7500
# Epoch 157/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4652 - accuracy: 0.7778 - val_loss: 0.4924 - val_accuracy: 0.7500
# Epoch 158/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4649 - accuracy: 0.7795 - val_loss: 0.4922 - val_accuracy: 0.7500
# Epoch 159/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4646 - accuracy: 0.7778 - val_loss: 0.4921 - val_accuracy: 0.7500
# Epoch 160/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4643 - accuracy: 0.7795 - val_loss: 0.4920 - val_accuracy: 0.7500
# Epoch 161/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4640 - accuracy: 0.7795 - val_loss: 0.4918 - val_accuracy: 0.7500
# Epoch 162/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4638 - accuracy: 0.7795 - val_loss: 0.4917 - val_accuracy: 0.7500
# Epoch 163/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4635 - accuracy: 0.7795 - val_loss: 0.4916 - val_accuracy: 0.7500
# Epoch 164/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4632 - accuracy: 0.7795 - val_loss: 0.4915 - val_accuracy: 0.7448
# Epoch 165/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4630 - accuracy: 0.7778 - val_loss: 0.4913 - val_accuracy: 0.7448
# Epoch 166/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4627 - accuracy: 0.7795 - val_loss: 0.4912 - val_accuracy: 0.7448
# Epoch 167/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4624 - accuracy: 0.7795 - val_loss: 0.4911 - val_accuracy: 0.7448
# Epoch 168/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4621 - accuracy: 0.7795 - val_loss: 0.4910 - val_accuracy: 0.7448
# Epoch 169/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4619 - accuracy: 0.7795 - val_loss: 0.4909 - val_accuracy: 0.7448
# Epoch 170/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4616 - accuracy: 0.7795 - val_loss: 0.4908 - val_accuracy: 0.7448
# Epoch 171/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4614 - accuracy: 0.7812 - val_loss: 0.4907 - val_accuracy: 0.7448
# Epoch 172/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4612 - accuracy: 0.7812 - val_loss: 0.4906 - val_accuracy: 0.7448
# Epoch 173/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4609 - accuracy: 0.7812 - val_loss: 0.4905 - val_accuracy: 0.7448
# Epoch 174/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4606 - accuracy: 0.7830 - val_loss: 0.4904 - val_accuracy: 0.7448
# Epoch 175/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4604 - accuracy: 0.7812 - val_loss: 0.4903 - val_accuracy: 0.7448
# Epoch 176/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4602 - accuracy: 0.7812 - val_loss: 0.4902 - val_accuracy: 0.7448
# Epoch 177/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4599 - accuracy: 0.7795 - val_loss: 0.4901 - val_accuracy: 0.7448
# Epoch 178/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4597 - accuracy: 0.7830 - val_loss: 0.4901 - val_accuracy: 0.7448
# Epoch 179/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4594 - accuracy: 0.7812 - val_loss: 0.4900 - val_accuracy: 0.7448
# Epoch 180/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4592 - accuracy: 0.7830 - val_loss: 0.4899 - val_accuracy: 0.7448
# Epoch 181/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4590 - accuracy: 0.7830 - val_loss: 0.4899 - val_accuracy: 0.7448
# Epoch 182/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4587 - accuracy: 0.7830 - val_loss: 0.4898 - val_accuracy: 0.7448
# Epoch 183/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4585 - accuracy: 0.7812 - val_loss: 0.4898 - val_accuracy: 0.7448
# Epoch 184/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4583 - accuracy: 0.7830 - val_loss: 0.4897 - val_accuracy: 0.7448
# Epoch 185/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4581 - accuracy: 0.7830 - val_loss: 0.4897 - val_accuracy: 0.7448
# Epoch 186/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4578 - accuracy: 0.7812 - val_loss: 0.4896 - val_accuracy: 0.7448
# Epoch 187/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4576 - accuracy: 0.7812 - val_loss: 0.4896 - val_accuracy: 0.7448
# Epoch 188/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4574 - accuracy: 0.7830 - val_loss: 0.4896 - val_accuracy: 0.7448
# Epoch 189/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4572 - accuracy: 0.7830 - val_loss: 0.4895 - val_accuracy: 0.7448
# Epoch 190/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4570 - accuracy: 0.7830 - val_loss: 0.4895 - val_accuracy: 0.7448
# Epoch 191/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4567 - accuracy: 0.7812 - val_loss: 0.4895 - val_accuracy: 0.7500
# Epoch 192/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4565 - accuracy: 0.7812 - val_loss: 0.4895 - val_accuracy: 0.7500
# Epoch 193/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4563 - accuracy: 0.7847 - val_loss: 0.4895 - val_accuracy: 0.7500
# Epoch 194/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4561 - accuracy: 0.7865 - val_loss: 0.4894 - val_accuracy: 0.7500
# Epoch 195/200
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4559 - accuracy: 0.7847 - val_loss: 0.4894 - val_accuracy: 0.7500
# Epoch 196/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4557 - accuracy: 0.7865 - val_loss: 0.4894 - val_accuracy: 0.7500
# Epoch 197/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4555 - accuracy: 0.7847 - val_loss: 0.4894 - val_accuracy: 0.7500
# Epoch 198/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4554 - accuracy: 0.7847 - val_loss: 0.4894 - val_accuracy: 0.7500
# Epoch 199/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4551 - accuracy: 0.7847 - val_loss: 0.4894 - val_accuracy: 0.7500
# Epoch 200/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4549 - accuracy: 0.7865 - val_loss: 0.4893 - val_accuracy: 0.7500

# %%
## Like we did for the Random Forest, we generate two kinds of predictions
#  One is a hard decision, the other is a probabilitistic score.

y_pred_class_nn_1 = model.predict(X_test_norm)
y_pred_prob_nn_1 = model.predict(X_test_norm)
# Out:
# 6/6 [==============================] - 0s 0s/step
# 6/6 [==============================] - 0s 800us/step

# %%
# Let's check out the outputs to get a feel for how keras apis work.
y_pred_class_nn_1[:10]
# Out:
# array([[0.49152526],
#        [0.72274804],
#        [0.3365187 ],
#        [0.35766202],
#        [0.15391308],
#        [0.48094973],
#        [0.04510643],
#        [0.3103733 ],
#        [0.88053066],
#        [0.19987218]], dtype=float32)

# %%
y_pred_prob_nn_1[:10]
# Out:
# array([[0.49152526],
#        [0.72274804],
#        [0.3365187 ],
#        [0.35766202],
#        [0.15391308],
#        [0.48094973],
#        [0.04510643],
#        [0.3103733 ],
#        [0.88053066],
#        [0.19987218]], dtype=float32)

# %% [markdown]
# Create the plot_roc function

# %%
def plot_roc(y_test, y_pred, model_name):
    fpr, tpr, thr = roc_curve(y_test, y_pred)
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.plot(fpr, tpr, 'k-')
    ax.plot([0, 1], [0, 1], 'k--', linewidth=.5)  # roc curve for random model
    ax.grid(True)
    ax.set(title='ROC Curve for {} on PIMA diabetes problem'.format(model_name),
           xlim=[-0.01, 1.01], ylim=[-0.01, 1.01])
    return

# %% [markdown]
# Evaluate the model performance and plot the ROC CURVE

# %%
print('accuracy is {:.3f}'.format(accuracy_score(y_test, np.round(y_pred_class_nn_1))))
print('roc-auc is {:.3f}'.format(roc_auc_score(y_test, y_pred_prob_nn_1)))

plot_roc(y_test, y_pred_prob_nn_1, 'NN')
# Out:
# accuracy is 0.750
# roc-auc is 0.813

# %% [markdown]
#  Plot the training loss and the validation loss over the different epochs and see how it looks

# %%
run_hist_1.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
fig, ax = plt.subplots()
ax.plot(run_hist_1.history["loss"],'r', marker='.', label="Train Loss")
ax.plot(run_hist_1.history["val_loss"],'b', marker='.', label="Validation Loss")
ax.legend()

# %% [markdown]
# What is your interpretation about the result of the train and validation loss?

# %% [markdown]
# #type your answer here

# %% [markdown]
# #### Supplementary Activity

# %% [markdown]
# * Build a model with two hidden layers, each with 6 nodes
# * Use the "relu" activation function for the hidden layers, and "sigmoid" for the final layer
# * Use a learning rate of .003 and train for 1500 epochs
# * Graph the trajectory of the loss functions, accuracy on both train and test set
# * Plot the roc curve for the predictions
# * Use different learning rates, numbers of epochs, and network structures.
# * Plot the results of training and validation loss using different learning rates, number of epocgs and network structures
# * Interpret your result

# %% [markdown]
# #### Conclusion

# %% [markdown]
# #type your answer here
